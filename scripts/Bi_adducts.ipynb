# %%
from utilities.molecule import Molecule, Element
from utilities.periodic_table import get_periodic_table
from utilities.SIMS_Spectra_class import SIMS_Spectra
import numpy as np
import pandas as pd
import os
import shutil
import re
from scipy.ndimage import gaussian_filter1d
import plotly.graph_objects as go
import re
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator, ScalarFormatter)

# %%
positive_filename_list = []
negative_filename_list = []
directory_name = "../data/ToF-SIMS_data/raw_spectra"
for filename in os.listdir(directory_name):
    if re.match("P_", filename):
        positive_filename_list.append(os.path.join(directory_name, filename))
    elif re.match("N_", filename):
        negative_filename_list.append(os.path.join(directory_name, filename))
positive_filename_list.sort(reverse=True)
negative_filename_list.sort(reverse=True)

# %% [markdown]
# # Creation of a DF containing all the Bi adducts detected

# %%
single_element = ["H", "K", "Na", "Cu", "Zn", "Al", "CH3", "C2H5"]
other_elements = ["Bi"]

# Creation of a dict holding all the isotopes lists and isotope dfs to avoid to compute them each time 
isotope_df_dict = {"Ru":None,
                   "Ru-Pt":None,
                   "Ru-Pd":None,
                   "Ru-Ir":None,
                   "Ru-Rh":None,
                   "Ru-Pt-Pd":None,
                   "Ru-Pt-Pd-Ir":None,
                   "Ru-Pt-Pd-Ir-Rh": None,
                   "HEA19": None,
                   "HEA 1.2": None}

df_all = pd.DataFrame()
for path in positive_filename_list:
    sample_name_index = np.where(["_"+x+"_" in path for x in isotope_df_dict.keys()])[0].item()
    sample_name = list(isotope_df_dict.keys())[sample_name_index]
    
    if sample_name == "HEA19" or sample_name == "HEA 1.2":
        sample_name = "Ru-Pt-Pd-Ir-Rh"
    sample_components = sample_name.split("-")

    if isotope_df_dict.get(sample_name) is None :
        spectra = SIMS_Spectra(path,
                                components = sample_components, 
                                single_other_component= single_element,
                                other_elements=other_elements,
                                indice_max=5,
                                max_molecules=4,
                                highest_peak_mz=1800)
        df = spectra.get_output_df()
        isotope_df_dict[sample_name] = (spectra.isotopes, spectra.isotopes_df)
    
    else : 
        sample_isotopes = isotope_df_dict.get(sample_name)[0]
        sample_isotope_df = isotope_df_dict.get(sample_name)[1]
        spectra = SIMS_Spectra(path,
                               single_other_component= single_element,
                               other_elements= other_elements,
                               indice_max=5,
                               max_molecules=4,
                               isotopes_df=sample_isotope_df,
                               isotopes=sample_isotopes,
                               highest_peak_mz=1800)
        df = spectra.get_output_df()
    
    df_all = pd.concat([df_all, df], ignore_index=True)
df_all.fillna(0, inplace=True)

# Remove Columns where the quantification value is 0 for all the samples
df_all_cleaned = df_all.loc[:,(df_all !=0).any().values]
df_all_cleaned.to_csv("../data/ToF-SIMS_data/processed_spectra/AllSample_PositiveMode_BiAdducts_ProcessedData.csv", index=False)
# Out:
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru_Bi5_3.txt'
#
# Creation of the Isotope DataFrame with ['Ru'] up to 5 indices for the mz range of 0 to 1800
# 100%|██████████| 19/19 [00:00<00:00, 258.62it/s]
# Isotope DataFrame created, 19 isotopes considered for quantification
# Quantification done --> 19 molecules out of 19 where quantified in the spectra
# Residual of the fit: 26195
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru_Bi5_2.txt'
#
# Quantification done --> 19 molecules out of 19 where quantified in the spectra
# Residual of the fit: 34955
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru_Bi5_1.txt'
#
# Quantification done --> 19 molecules out of 19 where quantified in the spectra
# Residual of the fit: 34439
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru_Bi3_1.txt'
#
# isotope df of shape (3598, 20) does not match with bin_mz array of shape (1816,)...
# Isotope df reshaped to (1816, 19)
# Quantification done --> 19 molecules out of 19 where quantified in the spectra
# Residual of the fit: 137088
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru_Bi1_1.txt'
#
# isotope df of shape (3598, 20) does not match with bin_mz array of shape (1717,)...
# Isotope df reshaped to (1717, 19)
# Quantification done --> 19 molecules out of 19 where quantified in the spectra
# Residual of the fit: 57889
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi5_5.txt'
#
# Creation of the Isotope DataFrame with ['Ru', 'Rh'] up to 5 indices for the mz range of 0 to 1800
# 100%|██████████| 49/49 [00:00<00:00, 203.01it/s]
# Isotope DataFrame created, 49 isotopes considered for quantification
# Quantification done --> 35 molecules out of 49 where quantified in the spectra
# Residual of the fit: 173015
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi5_4.txt'
#
# Quantification done --> 36 molecules out of 49 where quantified in the spectra
# Residual of the fit: 174891
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi5_3.txt'
#
# Quantification done --> 37 molecules out of 49 where quantified in the spectra
# Residual of the fit: 206217
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi5_2.txt'
#
# Quantification done --> 39 molecules out of 49 where quantified in the spectra
# Residual of the fit: 246116
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi5_1.txt'
#
# Quantification done --> 36 molecules out of 49 where quantified in the spectra
# Residual of the fit: 290706
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi3_5.txt'
#
# Quantification done --> 39 molecules out of 49 where quantified in the spectra
# Residual of the fit: 574546
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi3_4.txt'
#
# isotope df of shape (3598, 50) does not match with bin_mz array of shape (3599,)...
# bin_mz array reshaped to (3598,)
# Quantification done --> 42 molecules out of 49 where quantified in the spectra
# Residual of the fit: 563099
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi3_3.txt'
#
# Quantification done --> 41 molecules out of 49 where quantified in the spectra
# Residual of the fit: 758755
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi3_2.txt'
#
# Quantification done --> 42 molecules out of 49 where quantified in the spectra
# Residual of the fit: 921956
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi3_1.txt'
#
# Quantification done --> 43 molecules out of 49 where quantified in the spectra
# Residual of the fit: 975445
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi3++_5.txt'
#
# Quantification done --> 38 molecules out of 49 where quantified in the spectra
# Residual of the fit: 380164
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi3++_4.txt'
#
# Quantification done --> 39 molecules out of 49 where quantified in the spectra
# Residual of the fit: 412388
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi3++_3.txt'
#
# Quantification done --> 40 molecules out of 49 where quantified in the spectra
# Residual of the fit: 419325
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi3++_2.txt'
#
# Quantification done --> 37 molecules out of 49 where quantified in the spectra
# Residual of the fit: 299132
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi3++_1.txt'
#
# Quantification done --> 37 molecules out of 49 where quantified in the spectra
# Residual of the fit: 336259
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi1_5.txt'
#
# Quantification done --> 35 molecules out of 49 where quantified in the spectra
# Residual of the fit: 981613
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi1_4.txt'
#
# Quantification done --> 37 molecules out of 49 where quantified in the spectra
# Residual of the fit: 1210555
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi1_3.txt'
#
# Quantification done --> 39 molecules out of 49 where quantified in the spectra
# Residual of the fit: 1298138
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi1_2.txt'
#
# Quantification done --> 43 molecules out of 49 where quantified in the spectra
# Residual of the fit: 760669
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Rh_Bi1_1.txt'
#
# Quantification done --> 44 molecules out of 49 where quantified in the spectra
# Residual of the fit: 1014832
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi5_5.txt'
#
# Creation of the Isotope DataFrame with ['Ru', 'Pt'] up to 5 indices for the mz range of 0 to 1800
# 100%|██████████| 49/49 [00:00<00:00, 63.18it/s]
# Isotope DataFrame created, 49 isotopes considered for quantification
# Quantification done --> 42 molecules out of 49 where quantified in the spectra
# Residual of the fit: 116418
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi5_4.txt'
#
# Quantification done --> 43 molecules out of 49 where quantified in the spectra
# Residual of the fit: 155091
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi5_3.txt'
#
# Quantification done --> 42 molecules out of 49 where quantified in the spectra
# Residual of the fit: 478272
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi5_2.txt'
#
# Quantification done --> 43 molecules out of 49 where quantified in the spectra
# Residual of the fit: 188962
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi5_1.txt'
#
# Quantification done --> 43 molecules out of 49 where quantified in the spectra
# Residual of the fit: 182827
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi3_5.txt'
#
# Quantification done --> 43 molecules out of 49 where quantified in the spectra
# Residual of the fit: 361884
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi3_4.txt'
#
# isotope df of shape (3601, 50) does not match with bin_mz array of shape (3600,)...
# Isotope df reshaped to (3600, 49)
# Quantification done --> 43 molecules out of 49 where quantified in the spectra
# Residual of the fit: 414571
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi3_3.txt'
#
# isotope df of shape (3601, 50) does not match with bin_mz array of shape (3600,)...
# Isotope df reshaped to (3600, 49)
# Quantification done --> 43 molecules out of 49 where quantified in the spectra
# Residual of the fit: 1214099
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi3_2.txt'
#
# Quantification done --> 42 molecules out of 49 where quantified in the spectra
# Residual of the fit: 512705
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi3_1.txt'
#
# isotope df of shape (3601, 50) does not match with bin_mz array of shape (3600,)...
# Isotope df reshaped to (3600, 49)
# Quantification done --> 42 molecules out of 49 where quantified in the spectra
# Residual of the fit: 688166
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi3++_5.txt'
#
# Quantification done --> 43 molecules out of 49 where quantified in the spectra
# Residual of the fit: 165206
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi3++_4.txt'
#
# Quantification done --> 42 molecules out of 49 where quantified in the spectra
# Residual of the fit: 183278
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi3++_3.txt'
#
# Quantification done --> 43 molecules out of 49 where quantified in the spectra
# Residual of the fit: 564729
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi3++_2.txt'
#
# Quantification done --> 42 molecules out of 49 where quantified in the spectra
# Residual of the fit: 231991
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi3++_1.txt'
#
# Quantification done --> 43 molecules out of 49 where quantified in the spectra
# Residual of the fit: 308647
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi1_5.txt'
#
# Quantification done --> 42 molecules out of 49 where quantified in the spectra
# Residual of the fit: 247577
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi1_4.txt'
#
# isotope df of shape (3601, 50) does not match with bin_mz array of shape (3600,)...
# Isotope df reshaped to (3600, 49)
# Quantification done --> 42 molecules out of 49 where quantified in the spectra
# Residual of the fit: 208176
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi1_3.txt'
#
# Quantification done --> 43 molecules out of 49 where quantified in the spectra
# Residual of the fit: 623700
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi1_2.txt'
#
# isotope df of shape (3601, 50) does not match with bin_mz array of shape (3600,)...
# Isotope df reshaped to (3600, 49)
# Quantification done --> 42 molecules out of 49 where quantified in the spectra
# Residual of the fit: 304806
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt_Bi1_1.txt'
#
# Quantification done --> 42 molecules out of 49 where quantified in the spectra
# Residual of the fit: 363896
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi5_5.txt'
#
# Creation of the Isotope DataFrame with ['Ru', 'Pt', 'Pd'] up to 5 indices for the mz range of 0 to 1800
# 100%|██████████| 223/223 [00:09<00:00, 23.26it/s]
# Isotope DataFrame created, 223 isotopes considered for quantification
# Quantification done --> 93 molecules out of 223 where quantified in the spectra
# Residual of the fit: 36363
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi5_4.txt'
#
# Quantification done --> 89 molecules out of 223 where quantified in the spectra
# Residual of the fit: 31002
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi5_3.txt'
#
# Quantification done --> 90 molecules out of 223 where quantified in the spectra
# Residual of the fit: 468408
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi5_2.txt'
#
# Quantification done --> 93 molecules out of 223 where quantified in the spectra
# Residual of the fit: 44632
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi5_1.txt'
#
# Quantification done --> 95 molecules out of 223 where quantified in the spectra
# Residual of the fit: 40771
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi3_5.txt'
#
# Quantification done --> 95 molecules out of 223 where quantified in the spectra
# Residual of the fit: 101354
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi3_4.txt'
#
# Quantification done --> 93 molecules out of 223 where quantified in the spectra
# Residual of the fit: 129837
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi3_3.txt'
#
# Quantification done --> 92 molecules out of 223 where quantified in the spectra
# Residual of the fit: 98634
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi3_2.txt'
#
# Quantification done --> 93 molecules out of 223 where quantified in the spectra
# Residual of the fit: 207172
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi3_1.txt'
#
# Quantification done --> 91 molecules out of 223 where quantified in the spectra
# Residual of the fit: 112795
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi3++_5.txt'
#
# Quantification done --> 89 molecules out of 223 where quantified in the spectra
# Residual of the fit: 43970
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi3++_4.txt'
#
# Quantification done --> 96 molecules out of 223 where quantified in the spectra
# Residual of the fit: 50378
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi3++_3.txt'
#
# Quantification done --> 87 molecules out of 223 where quantified in the spectra
# Residual of the fit: 45850
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi3++_2.txt'
#
# Quantification done --> 89 molecules out of 223 where quantified in the spectra
# Residual of the fit: 49835
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi3++_1.txt'
#
# Quantification done --> 90 molecules out of 223 where quantified in the spectra
# Residual of the fit: 47915
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi1_5.txt'
#
# Quantification done --> 82 molecules out of 223 where quantified in the spectra
# Residual of the fit: 119633
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi1_4.txt'
#
# Quantification done --> 88 molecules out of 223 where quantified in the spectra
# Residual of the fit: 142502
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi1_3.txt'
#
# Quantification done --> 82 molecules out of 223 where quantified in the spectra
# Residual of the fit: 86961
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi1_2.txt'
#
# Quantification done --> 85 molecules out of 223 where quantified in the spectra
# Residual of the fit: 94414
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd_Bi1_1.txt'
#
# isotope df of shape (3600, 224) does not match with bin_mz array of shape (3601,)...
# bin_mz array reshaped to (3600,)
# Quantification done --> 86 molecules out of 223 where quantified in the spectra
# Residual of the fit: 164818
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi5_5.txt'
#
# Creation of the Isotope DataFrame with ['Ru', 'Pt', 'Pd', 'Ir'] up to 5 indices for the mz range of 0 to 1800
# 100%|██████████| 949/949 [00:48<00:00, 19.43it/s]
# Isotope DataFrame created, 949 isotopes considered for quantification
# Quantification done --> 175 molecules out of 949 where quantified in the spectra
# Residual of the fit: 17948
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi5_4.txt'
#
# isotope df of shape (3599, 950) does not match with bin_mz array of shape (3598,)...
# Isotope df reshaped to (3598, 949)
# Quantification done --> 180 molecules out of 949 where quantified in the spectra
# Residual of the fit: 29344
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi5_3.txt'
#
# Quantification done --> 177 molecules out of 949 where quantified in the spectra
# Residual of the fit: 38365
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi5_2.txt'
#
# Quantification done --> 180 molecules out of 949 where quantified in the spectra
# Residual of the fit: 21772
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi5_1.txt'
#
# Quantification done --> 184 molecules out of 949 where quantified in the spectra
# Residual of the fit: 29516
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi3_5.txt'
#
# Quantification done --> 186 molecules out of 949 where quantified in the spectra
# Residual of the fit: 59200
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi3_4.txt'
#
# Quantification done --> 182 molecules out of 949 where quantified in the spectra
# Residual of the fit: 55702
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi3_3.txt'
#
# isotope df of shape (3599, 950) does not match with bin_mz array of shape (3598,)...
# Isotope df reshaped to (3598, 949)
# Quantification done --> 178 molecules out of 949 where quantified in the spectra
# Residual of the fit: 65048
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi3_2.txt'
#
# Quantification done --> 192 molecules out of 949 where quantified in the spectra
# Residual of the fit: 49314
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi3_1.txt'
#
# Quantification done --> 183 molecules out of 949 where quantified in the spectra
# Residual of the fit: 78101
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi3++_5.txt'
#
# Quantification done --> 180 molecules out of 949 where quantified in the spectra
# Residual of the fit: 30085
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi3++_4.txt'
#
# Quantification done --> 183 molecules out of 949 where quantified in the spectra
# Residual of the fit: 35858
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi3++_3.txt'
#
# Quantification done --> 173 molecules out of 949 where quantified in the spectra
# Residual of the fit: 35894
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi3++_2.txt'
#
# isotope df of shape (3599, 950) does not match with bin_mz array of shape (3598,)...
# Isotope df reshaped to (3598, 949)
# Quantification done --> 175 molecules out of 949 where quantified in the spectra
# Residual of the fit: 32438
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi3++_1.txt'
#
# Quantification done --> 167 molecules out of 949 where quantified in the spectra
# Residual of the fit: 26722
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi1_5.txt'
#
# isotope df of shape (3599, 950) does not match with bin_mz array of shape (3598,)...
# Isotope df reshaped to (3598, 949)
# Quantification done --> 158 molecules out of 949 where quantified in the spectra
# Residual of the fit: 74177
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi1_4.txt'
#
# isotope df of shape (3599, 950) does not match with bin_mz array of shape (3598,)...
# Isotope df reshaped to (3598, 949)
# Quantification done --> 170 molecules out of 949 where quantified in the spectra
# Residual of the fit: 44167
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi1_3.txt'
#
# isotope df of shape (3599, 950) does not match with bin_mz array of shape (3598,)...
# Isotope df reshaped to (3598, 949)
# Quantification done --> 171 molecules out of 949 where quantified in the spectra
# Residual of the fit: 43787
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi1_2.txt'
#
# isotope df of shape (3599, 950) does not match with bin_mz array of shape (3598,)...
# Isotope df reshaped to (3598, 949)
# Quantification done --> 168 molecules out of 949 where quantified in the spectra
# Residual of the fit: 46045
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir_Bi1_1.txt'
#
# isotope df of shape (3599, 950) does not match with bin_mz array of shape (3598,)...
# Isotope df reshaped to (3598, 949)
# Quantification done --> 154 molecules out of 949 where quantified in the spectra
# Residual of the fit: 30533
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir-Rh_Bi5_3.txt'
#
# Creation of the Isotope DataFrame with ['Ru', 'Pt', 'Pd', 'Ir', 'Rh'] up to 5 indices for the mz range of 0 to 1800
# 100%|██████████| 3367/3367 [03:21<00:00, 16.69it/s]
# Isotope DataFrame created, 3367 isotopes considered for quantification
# Quantification done --> 389 molecules out of 3367 where quantified in the spectra
# Residual of the fit: 29977
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir-Rh_Bi5_2.txt'
#
# Quantification done --> 411 molecules out of 3367 where quantified in the spectra
# Residual of the fit: 26196
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir-Rh_Bi5_1.txt'
#
# Quantification done --> 388 molecules out of 3367 where quantified in the spectra
# Residual of the fit: 25371
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir-Rh_Bi3_1.txt'
#
# isotope df of shape (3598, 3368) does not match with bin_mz array of shape (1807,)...
# Isotope df reshaped to (1807, 3367)
# Quantification done --> 163 molecules out of 3367 where quantified in the spectra
# Residual of the fit: 133793
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pt-Pd-Ir-Rh_Bi1_1.txt'
#
# isotope df of shape (3598, 3368) does not match with bin_mz array of shape (1825,)...
# Isotope df reshaped to (1825, 3367)
# Quantification done --> 149 molecules out of 3367 where quantified in the spectra
# Residual of the fit: 56994
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi5_5.txt'
#
# Creation of the Isotope DataFrame with ['Ru', 'Pd'] up to 5 indices for the mz range of 0 to 1800
# 100%|██████████| 49/49 [00:00<00:00, 62.36it/s]
# Isotope DataFrame created, 49 isotopes considered for quantification
# Quantification done --> 35 molecules out of 49 where quantified in the spectra
# Residual of the fit: 28869
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi5_4.txt'
#
# Quantification done --> 36 molecules out of 49 where quantified in the spectra
# Residual of the fit: 38816
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi5_3.txt'
#
# isotope df of shape (3600, 50) does not match with bin_mz array of shape (3599,)...
# Isotope df reshaped to (3599, 49)
# Quantification done --> 35 molecules out of 49 where quantified in the spectra
# Residual of the fit: 46695
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi5_2.txt'
#
# Quantification done --> 35 molecules out of 49 where quantified in the spectra
# Residual of the fit: 32819
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi5_1.txt'
#
# Quantification done --> 36 molecules out of 49 where quantified in the spectra
# Residual of the fit: 36575
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi3_5.txt'
#
# isotope df of shape (3600, 50) does not match with bin_mz array of shape (3599,)...
# Isotope df reshaped to (3599, 49)
# Quantification done --> 33 molecules out of 49 where quantified in the spectra
# Residual of the fit: 111195
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi3_4.txt'
#
# isotope df of shape (3600, 50) does not match with bin_mz array of shape (3599,)...
# Isotope df reshaped to (3599, 49)
# Quantification done --> 34 molecules out of 49 where quantified in the spectra
# Residual of the fit: 92843
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi3_3.txt'
#
# isotope df of shape (3600, 50) does not match with bin_mz array of shape (3599,)...
# Isotope df reshaped to (3599, 49)
# Quantification done --> 34 molecules out of 49 where quantified in the spectra
# Residual of the fit: 119380
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi3_2.txt'
#
# Quantification done --> 33 molecules out of 49 where quantified in the spectra
# Residual of the fit: 135715
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi3_1.txt'
#
# isotope df of shape (3600, 50) does not match with bin_mz array of shape (3599,)...
# Isotope df reshaped to (3599, 49)
# Quantification done --> 35 molecules out of 49 where quantified in the spectra
# Residual of the fit: 129921
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi3++_5.txt'
#
# Quantification done --> 33 molecules out of 49 where quantified in the spectra
# Residual of the fit: 64962
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi3++_4.txt'
#
# Quantification done --> 37 molecules out of 49 where quantified in the spectra
# Residual of the fit: 74065
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi3++_3.txt'
#
# isotope df of shape (3600, 50) does not match with bin_mz array of shape (3599,)...
# Isotope df reshaped to (3599, 49)
# Quantification done --> 34 molecules out of 49 where quantified in the spectra
# Residual of the fit: 49749
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi3++_2.txt'
#
# Quantification done --> 36 molecules out of 49 where quantified in the spectra
# Residual of the fit: 51847
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi3++_1.txt'
#
# Quantification done --> 38 molecules out of 49 where quantified in the spectra
# Residual of the fit: 746197
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi1_5.txt'
#
# isotope df of shape (3600, 50) does not match with bin_mz array of shape (3599,)...
# Isotope df reshaped to (3599, 49)
# Quantification done --> 35 molecules out of 49 where quantified in the spectra
# Residual of the fit: 88847
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi1_4.txt'
#
# isotope df of shape (3600, 50) does not match with bin_mz array of shape (3599,)...
# Isotope df reshaped to (3599, 49)
# Quantification done --> 33 molecules out of 49 where quantified in the spectra
# Residual of the fit: 98269
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi1_3.txt'
#
# isotope df of shape (3600, 50) does not match with bin_mz array of shape (3599,)...
# Isotope df reshaped to (3599, 49)
# Quantification done --> 34 molecules out of 49 where quantified in the spectra
# Residual of the fit: 73840
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi1_2.txt'
#
# Quantification done --> 35 molecules out of 49 where quantified in the spectra
# Residual of the fit: 59463
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Pd_Bi1_1.txt'
#
# isotope df of shape (3600, 50) does not match with bin_mz array of shape (3599,)...
# Isotope df reshaped to (3599, 49)
# Quantification done --> 34 molecules out of 49 where quantified in the spectra
# Residual of the fit: 173942
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Ir_Bi3_5.txt'
#
# Creation of the Isotope DataFrame with ['Ru', 'Ir'] up to 5 indices for the mz range of 0 to 1800
# 100%|██████████| 49/49 [00:00<00:00, 143.04it/s]
# Isotope DataFrame created, 49 isotopes considered for quantification
# Quantification done --> 46 molecules out of 49 where quantified in the spectra
# Residual of the fit: 607332
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Ir_Bi3_4.txt'
#
# isotope df of shape (3601, 50) does not match with bin_mz array of shape (3600,)...
# Isotope df reshaped to (3600, 49)
# Quantification done --> 46 molecules out of 49 where quantified in the spectra
# Residual of the fit: 709678
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Ir_Bi3_3.txt'
#
# isotope df of shape (3601, 50) does not match with bin_mz array of shape (3600,)...
# Isotope df reshaped to (3600, 49)
# Quantification done --> 46 molecules out of 49 where quantified in the spectra
# Residual of the fit: 565712
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Ir_Bi3_2.txt'
#
# Quantification done --> 46 molecules out of 49 where quantified in the spectra
# Residual of the fit: 407806
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Ir_Bi3_1.txt'
#
# Quantification done --> 46 molecules out of 49 where quantified in the spectra
# Residual of the fit: 497330
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Ir_Bi3++_2.txt'
#
# Quantification done --> 46 molecules out of 49 where quantified in the spectra
# Residual of the fit: 169769
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Ir_Bi3++_1.txt'
#
# Quantification done --> 46 molecules out of 49 where quantified in the spectra
# Residual of the fit: 122269
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Ir_Bi1_5.txt'
#
# Quantification done --> 46 molecules out of 49 where quantified in the spectra
# Residual of the fit: 943072
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Ir_Bi1_4.txt'
#
# Quantification done --> 46 molecules out of 49 where quantified in the spectra
# Residual of the fit: 1272660
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Ir_Bi1_3.txt'
#
# Quantification done --> 46 molecules out of 49 where quantified in the spectra
# Residual of the fit: 945399
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Ir_Bi1_2.txt'
#
# Quantification done --> 46 molecules out of 49 where quantified in the spectra
# Residual of the fit: 906969
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_Ru-Ir_Bi1_1.txt'
#
# Quantification done --> 46 molecules out of 49 where quantified in the spectra
# Residual of the fit: 1014091
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_HEA19_Bi5_3.txt'
#
# Quantification done --> 490 molecules out of 3367 where quantified in the spectra
# Residual of the fit: 175780
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_HEA19_Bi5_2.txt'
#
# Quantification done --> 483 molecules out of 3367 where quantified in the spectra
# Residual of the fit: 386543
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_HEA19_Bi5_1.txt'
#
# Quantification done --> 490 molecules out of 3367 where quantified in the spectra
# Residual of the fit: 325199
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_HEA19_Bi3_1.txt'
#
# isotope df of shape (3598, 3368) does not match with bin_mz array of shape (1728,)...
# Isotope df reshaped to (1728, 3367)
# Quantification done --> 183 molecules out of 3367 where quantified in the spectra
# Residual of the fit: 1691249
#
# ----------------------------------------------------------------------------------------------
#
# Spectra loaded from '../data/ToF-SIMS_data/raw_spectra/P_HEA19_Bi1_1.txt'
#
# isotope df of shape (3598, 3368) does not match with bin_mz array of shape (1775,)...
# Isotope df reshaped to (1775, 3367)
# Quantification done --> 170 molecules out of 3367 where quantified in the spectra
# Residual of the fit: 608844
#
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# # Comparaison of all the Bi adducts with all the

# %%
#pip install rpy2
# %load_ext rpy2.ipython

# %%
# %%R
#
# #install.packages('ggplot2')
# #install.packages('tidyverse')
# #install.packages('FactoMineR')
# #install.packages('factoextra')
# #install.packages('stringr')
# #install.packages('ggrepel')
# #install.packages('ggpubr')
# #install.packages('rstatix')
# #install.packages('upstartr')
# #install.packages('latex2exp')

# %%
# %%R
#
# library(tidyverse)
# library(readr)
# library(FactoMineR)
# library(factoextra)
# library(stringr)
# library(ggrepel)
# library(ggpubr)
# library(dplyr)
# library(rstatix)
# #library(upstartr)
# library(latex2exp)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
#
# Attaching package: ‘rstatix’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# In addition: Warning message:
# In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
#   libraries ‘/usr/local/lib/R/site-library’, ‘/usr/lib/R/site-library’ contain no packages

# %%
# %%R
#
#
# theme_set(theme_bw() +
#             theme(axis.text=element_text(size=12, colour="black"),
#         axis.title.x=element_blank(),
#         axis.title.y=element_text(size=14),
#         axis.text.x=element_text(size=13,face="bold"),
#         strip.text.x = element_text(size=13,face="bold")))
#
#
#
# # =======================================================
# #  - DATA RETRIEVAL
# # =======================================================
#
# automatic_positve_Bi_df <- read.csv("AllSample_PositiveMode_BiAdducts_ProcessedData.csv")
# automatic_positve_Bi_df$replicat <- as.factor(automatic_positve_Bi_df$replicat)
# automatic_positve_Bi_df$sample <- factor(automatic_positve_Bi_df$sample_name,
#                                        levels = c("Ru", "Ru-Pt", "Ru-Pd", "Ru-Ir",
#                                                   "Ru-Rh", "Ru-Pt-Pd", "Ru-Pt-Pd-Ir",
#                                                   "Ru-Pt-Pd-Ir-Rh", "HEA19", "HEA_1.2"))
#
# # Scaling the spectra by their total counts
# automatic_positve_Bi_df <- automatic_positve_Bi_df %>%
#   mutate("total_count" = rowSums(across(where(is.numeric))))
#
# scaled_automatic_positve_Bi_df <- automatic_positve_Bi_df %>% mutate(across(where(is.numeric) &!total_count,  ~ .x/total_count))

# %%
# %%R
#
# # Define the color palette for the samples
# sample_colors <- c("Ru" = "#e55e57" ,"Ru-Pt" = "#e5a273", "Ru-Pd" = "#ffd479",
#                    "Ru-Ir" = "#3bc093", "Ru-Rh" = "#07b5bc",
#                    "Ru-Pt-Pd" = "#509bdd", "Ru-Pt-Pd-Ir" = "#8d85e5",
#                    "HEA Mix" = "#b373d0", "HEA Seg" = "#D452AA")
#
# sample_names <- c("Ru" = "Ru", "Ru-Pt" = "Ru-Pt", "Ru-Pd" = "Ru-Pd",
#                   "Ru-Ir" = "Ru-Ir","Ru-Rh" = "Ru-Rh",
#                   "Ru-Pt-Pd" = "Ru-Pt-Pd",
#                   "Ru-Pt-Pd-Ir" = "Ru-Pt-Pd-Ir",
#                   "Ru-Pt-Pd-Ir-Rh" = "HEA Mix",
#                   "HEA19" = "HEA Seg")
# scaled_automatic_positve_Bi_df %>%
#   mutate(Bi_all = rowSums(across(contains("Bi"))),
#          NotBi_all = rowSums(across(is.numeric &!contains("Bi") & (contains("Ru") |
#                                               contains("Pt") | contains("Pd") | contains("Ir") | contains("Rh"))))) %>%
#   select(sample, primary_ion, NotBi_all, Bi_all) %>%
#   subset(primary_ion == "Bi5" &
#            sample != "HEA_1.2") %>%
#   group_by(sample) %>%
#   summarise(across(is.numeric,
#                    list(mean=~mean(.x), se = ~sd(.x)/sqrt(n())),
#                    .names = "{col}-{fn}")) %>%
#   pivot_longer(!sample, names_sep = "-", names_to = c("variable", "stat")) %>%
#   pivot_wider(names_from = stat, values_from = value) %>%
#   ggplot(aes(x = sample, color = variable)) +
#   geom_point(aes( y = mean)) +
#   geom_errorbar(aes(ymin = mean - se, ymax = mean + se)) +
#   scale_y_log10() +
#   annotation_logticks(scaled = T, side = "l") +
#   ylab("Scaled Intensity") +
#   labs(color = "Secondary ions")+
#   scale_x_discrete(labels=c("Ru-Ir" = "Ru-Ir", "Ru-Pd" = "Ru-Pd", "RuPtPd" = "Ru-Pt-Pd",
#                                "RuPtPdIr" = "Ru-Pt-Pd-Ir", "Ru-Pt-Pd-Ir-Rh" = "HEA Mix",
#                             "HEA19" = "HEA Seg"))+
#   scale_color_manual(labels = c("Containing Bi", "Not Containing Bi"), values = c("brown2", "turquoise3"))+
#   theme(axis.text.x = element_text(size = 14, angle = 45, hjust = 1, color = sample_colors, face = "bold"),
#         axis.text.y = element_text(size = 14, color = "black", face = "bold"),
#         legend.text = element_text(size=12, face = "bold"),
#         legend.title = element_text(size=14, face = "bold"))
